# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline

# %%
# setting max columns
pd.set_option('display.max_columns', None)

# %%
# checking current working directory
os.getcwd()
# Out:
# '/Users/Mateo/Springboard/Guided_Capstone'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
# loading the data from Step2

df = pd.read_csv('./data/step2_output.csv', index_col=0)

# %%
df.head(40)
# Out:
#                              Name       state  vertical_drop  base_elev  \
# 0                  Alyeska Resort      Alaska           2500        250
# 1             Eaglecrest Ski Area      Alaska           1540       1200
# 2                Hilltop Ski Area      Alaska            294       1796
# 3                Arizona Snowbowl     Arizona           2300       9200
# 4             Sunrise Park Resort     Arizona           1800       9200
# 5   Yosemite Ski & Snowboard Area  California            600       7200
# 6                   Bear Mountain  California           1665       7140
# 7                     Bear Valley  California           1900       6600
# 8          Boreal Mountain Resort  California            500       7200
# 9                     Dodge Ridge  California           1600       6600
# 10               Donner Ski Ranch  California            750       7031
# 11       Heavenly Mountain Resort  California           3500       7170
# 12                  June Mountain  California           2590       7545
# 13                       Kirkwood  California           2000       7800
# 14      Mammoth Mountain Ski Area  California           3100       7953
# 15            Mt. Shasta Ski Park  California           1435       5500
# 16                  Mountain High  California           1600       6600
# 17                      Mt. Baldy  California           2100       6500
# 18           Northstar California  California           2280       6330
# 19                Sierra-at-Tahoe  California           2212       6640
# 20                 Ski China Peak  California           1679       7030
# 21                    Snow Summit  California           1200       7000
# 22                    Snow Valley  California           1041       6800
# 23                   Soda Springs  California            652       6700
# 24              Sugar Bowl Resort  California           1500       6883
# 25                   Tahoe Donner  California            600       6750
# 26        Arapahoe Basin Ski Area    Colorado           2530      10780
# 27               Aspen / Snowmass    Colorado           4406       8104
# 28                   Beaver Creek    Colorado           3340       8100
# 29                   Breckenridge    Colorado           3398       9600
# 30         Copper Mountain Resort    Colorado           2738       9712
# 31  Crested Butte Mountain Resort    Colorado           3062       9375
# 32                      Purgatory    Colorado           2029       8793
# 33         Eldora Mountain Resort    Colorado           1400       9200
# 34                  Howelsen Hill    Colorado            440       6696
# 35                       Keystone    Colorado           3128       9280
# 36                       Loveland    Colorado           2210      10800
# 37               Monarch Mountain    Colorado           1162      10790
# 38                     Powderhorn    Colorado           1650       8200
# 39             Silverton Mountain    Colorado           3087      10400
#
#     trams  fastEight  fastSixes  fastQuads  quad  triple  double  surface  \
# 0       1        0.0          0          2     2       0       0        2
# 1       0        0.0          0          0     0       0       4        0
# 2       0        0.0          0          0     0       1       0        2
# 3       0        0.0          1          0     2       2       1        2
# 4       0        0.0          0          1     2       3       1        0
# 5       0        0.0          0          0     0       1       3        1
# 6       0        0.0          0          2     1       2       3        4
# 7       0        0.0          1          1     0       2       4        2
# 8       0        0.0          0          1     1       3       1        2
# 9       0        0.0          0          0     1       2       5        4
# 10      0        0.0          0          0     0       1       5        2
# 11      2        0.0          2          7     1       5       3        8
# 12      0        0.0          0          2     0       0       4        1
# 13      0        0.0          0          2     1       5       1        3
# 14      3        0.0          2          9     1       6       4        0
# 15      0        0.0          0          0     0       3       0        1
# 16      0        0.0          0          2     2       2       5        3
# 17      0        0.0          0          0     0       0       4        0
# 18      2        0.0          1          7     1       2       0        7
# 19      0        0.0          0          3     0       1       5        5
# 20      0        0.0          0          0     1       4       2        4
# 21      0        0.0          0          2     0       4       5        5
# 22      0        0.0          0          0     0       5       6        1
# 23      0        0.0          0          0     0       1       1        2
# 24      1        0.0          0          5     3       1       0        2
# 25      0        0.0          0          0     1       1       0        3
# 26      0        0.0          0          1     2       1       2        3
# 27      3        0.0          1         15     4       3       5        9
# 28      2        0.0          0         11     0       1       1        9
# 29      1        0.0          5          6     0       1       6       15
# 30      1        0.0          2          4     0       4       4        9
# 31      0        0.0          0          4     2       2       1        5
# 32      0        0.0          1          2     0       3       3        3
# 33      0        0.0          1          0     2       1       3        3
# 34      0        0.0          0          0     0       0       1        3
# 35      2        0.0          2          4     1       1       2        8
# 36      0        0.0          0          1     3       3       2        1
# 37      0        0.0          0          0     1       0       4        2
# 38      0        0.0          0          1     0       0       2        2
# 39      0        0.0          0          0     0       0       1        0
#
#     total_chairs        Runs  TerrainParks  LongestRun_mi  SkiableTerrain_ac  \
# 0              7   76.000000      2.000000            1.0             1610.0
# 1              4   36.000000      1.000000            2.0              640.0
# 2              3   13.000000      1.000000            1.0               30.0
# 3              8   55.000000      4.000000            2.0              777.0
# 4              7   65.000000      2.000000            1.2              800.0
# 5              5   10.000000      2.000000            0.4               88.0
# 6             12   27.000000     14.000000            1.5              198.0
# 7             10   67.000000      2.000000            1.2             1680.0
# 8              8   33.000000      6.000000            1.0              380.0
# 9             12   67.000000      5.000000            2.0              862.0
# 10             8   52.000000      2.000000            1.5              505.0
# 11            28   97.000000      3.000000            5.5             4800.0
# 12             7   41.000000      2.000000            2.0             1500.0
# 13            12   85.000000      2.000000            2.5             2300.0
# 14            25  154.000000      7.000000            3.0             3500.0
# 15             4   32.000000      2.000000            1.1              425.0
# 16            14   59.000000      1.000000            1.6              290.0
# 17             4   26.000000      2.820789            2.5              400.0
# 18            20  100.000000      9.000000            1.4             3170.0
# 19            14   46.000000      6.000000            2.5             2000.0
# 20            11   45.000000      1.000000            2.2             1400.0
# 21            16   27.000000      6.000000            1.2              240.0
# 22            12   28.000000      6.000000            1.2              240.0
# 23             4   18.000000      2.820789            0.4              200.0
# 24            12  105.000000      3.000000            3.0             1650.0
# 25             5   14.000000      2.000000            1.0              120.0
# 26             9  145.000000      3.000000            1.5             1428.0
# 27            40  336.000000     10.000000            5.3             5517.0
# 28            24  150.000000      3.000000            2.8             1832.0
# 29            34  187.000000      4.000000            3.5             2908.0
# 30            24  150.000000      6.000000            1.7             2527.0
# 31            14  121.000000      4.000000            2.6             1547.0
# 32            12  101.000000      9.000000            1.3             1605.0
# 33            10   65.000000      8.000000            3.0              680.0
# 34             4   17.000000      1.000000            6.0               50.0
# 35            20  128.000000      1.000000            3.5             3148.0
# 36            10   94.000000      1.000000            2.0             1800.0
# 37             7   64.000000      2.000000            1.0              800.0
# 38             5   42.000000      2.000000            1.5             1600.0
# 39             1   48.214724      2.820789            1.5            26819.0
#
#     Snow Making_ac  daysOpenLastYear  yearsOpen  averageSnowfall  \
# 0       113.000000        150.000000       60.0            669.0
# 1        60.000000         45.000000       44.0            350.0
# 2        30.000000        150.000000       36.0             69.0
# 3       104.000000        122.000000       81.0            260.0
# 4        80.000000        115.000000       49.0            250.0
# 5       174.873239        110.000000       84.0            300.0
# 6       198.000000        122.000000       76.0            100.0
# 7       100.000000        165.000000       52.0            359.0
# 8       200.000000        150.000000       54.0            400.0
# 9       174.873239        115.103943       69.0            350.0
# 10       60.000000        163.000000       82.0            400.0
# 11     3379.000000        155.000000       64.0            360.0
# 12      174.873239        115.103943       58.0            250.0
# 13      200.000000        200.000000       47.0            354.0
# 14      700.000000        243.000000       66.0            400.0
# 15      225.000000        140.000000       34.0            300.0
# 16      275.000000        118.000000       95.0            108.0
# 17       80.000000        175.000000       67.0            178.0
# 18     1500.000000        135.000000       47.0            350.0
# 19      200.000000        160.000000       73.0            460.0
# 20      150.000000        140.000000       62.0            300.0
# 21      240.000000        115.103943       67.0            100.0
# 22      188.000000        111.000000       82.0            160.0
# 23       20.000000        150.000000       83.0            400.0
# 24      375.000000        151.000000       80.0            500.0
# 25      174.873239        150.000000       48.0            400.0
# 26      125.000000        230.000000       73.0            350.0
# 27      658.000000        138.000000       72.0            300.0
# 28      650.000000        145.000000       39.0            323.0
# 29      600.000000        182.000000       58.0            300.0
# 30      364.000000        164.000000       47.0            300.0
# 31      297.000000        145.000000       58.0            234.0
# 32      250.000000        130.000000       54.0            260.0
# 33      680.000000        147.000000       57.0            311.0
# 34       25.000000        100.000000      104.0            150.0
# 35      662.000000        184.000000       49.0            235.0
# 36      240.000000        205.000000       82.0            422.0
# 37      174.873239        143.000000       80.0            350.0
# 38       42.000000        111.000000       53.0            250.0
# 39      174.873239        175.000000       17.0            400.0
#
#     AdultWeekday  AdultWeekend  NightSkiing_ac
# 0      65.000000      85.00000      550.000000
# 1      47.000000      53.00000      100.395722
# 2      30.000000      34.00000       30.000000
# 3      89.000000      89.00000      100.395722
# 4      74.000000      78.00000       80.000000
# 5      47.000000      47.00000      100.395722
# 6      57.916957      64.16681      100.395722
# 7      57.916957      64.16681      100.395722
# 8      49.000000      64.16681      200.000000
# 9      78.000000      78.00000      100.395722
# 10     75.000000      75.00000      100.395722
# 11     57.916957      64.16681      100.395722
# 12     57.916957      64.16681      100.395722
# 13     57.916957      64.16681      100.395722
# 14    149.000000     159.00000      100.395722
# 15     49.000000      59.00000      100.395722
# 16     84.000000      84.00000       73.000000
# 17     69.000000      69.00000      100.395722
# 18     57.916957      64.16681      100.395722
# 19     99.000000      64.16681      100.395722
# 20     83.000000      83.00000      100.395722
# 21     57.916957      64.16681      150.000000
# 22     69.000000      79.00000      164.000000
# 23     50.000000      50.00000      100.395722
# 24    125.000000     125.00000      100.395722
# 25     69.000000      69.00000      100.395722
# 26     85.000000      85.00000      100.395722
# 27    179.000000     179.00000      100.395722
# 28     57.916957      64.16681      100.395722
# 29     57.916957      64.16681      100.395722
# 30    158.000000     158.00000      100.395722
# 31     57.916957      64.16681      100.395722
# 32     89.000000      89.00000      100.395722
# 33     57.916957      64.16681      100.395722
# 34     25.000000      25.00000       10.000000
# 35     57.916957      64.16681      288.000000
# 36     79.000000      79.00000      100.395722
# 37     89.000000      89.00000      100.395722
# 38     71.000000      71.00000      100.395722
# 39     79.000000      79.00000      100.395722

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
# tranposing describe() summary statistics.
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.820789     1.845918    1.0     2.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   174.873239   242.378848    2.0    55.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.656535   109.263494    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   119.776431    30.564328   30.0   100.00
# NightSkiing_ac     330.0   100.395722    79.076753    2.0    60.00
#
#                            50%          75%      max
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.820789     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac      132.500000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   115.551971   137.000000    305.0
# NightSkiing_ac      100.395722   100.395722    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
fig = plt.figure(figsize = (16,14))
ax = fig.gca()
df.hist(bins=25, ax = ax)
plt.show()
# Out:
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
corr_mat = df.corr()
corr_mat
# Out:
#                    summit_elev  vertical_drop  base_elev     trams  \
# summit_elev           1.000000       0.735859   0.979080  0.342588
# vertical_drop         0.735859       1.000000   0.587713  0.587676
# base_elev             0.979080       0.587713   1.000000  0.234040
# trams                 0.342588       0.587676   0.234040  1.000000
# fastEight             0.097174       0.182597   0.073086  0.081576
# fastSixes             0.264926       0.377766   0.209398  0.528622
# fastQuads             0.449338       0.679942   0.338322  0.664149
# quad                 -0.012729       0.141729  -0.059273  0.222549
# triple                0.183979       0.263594   0.147100  0.266528
# double                0.106680       0.171421   0.080290  0.073272
# surface              -0.039470       0.085946  -0.067700  0.267745
# total_chairs          0.301986       0.548563   0.203831  0.651348
# Runs                  0.573033       0.797288   0.451071  0.685665
# TerrainParks          0.168547       0.341261   0.105118  0.325465
# LongestRun_mi         0.529771       0.759227   0.413270  0.568705
# SkiableTerrain_ac     0.468912       0.530349   0.406045  0.342238
# Snow Making_ac        0.316131       0.466209   0.246614  0.537990
# daysOpenLastYear      0.426314       0.534877   0.355968  0.354562
# yearsOpen            -0.024759      -0.031188  -0.019304 -0.009907
# averageSnowfall       0.693432       0.664244   0.633957  0.293778
# AdultWeekday          0.469810       0.626737   0.375532  0.414193
# AdultWeekend          0.382354       0.584300   0.283062  0.409995
# projectedDaysOpen     0.425014       0.550991   0.350272  0.332103
# NightSkiing_ac        0.142296       0.203536   0.103984  0.040943
#
#                       fastEight  fastSixes  fastQuads      quad    triple  \
# summit_elev        9.717395e-02   0.264926   0.449338 -0.012729  0.183979
# vertical_drop      1.825968e-01   0.377766   0.679942  0.141729  0.263594
# base_elev          7.308640e-02   0.209398   0.338322 -0.059273  0.147100
# trams              8.157621e-02   0.528622   0.664149  0.222549  0.266528
# fastEight          1.000000e+00   0.153793   0.100013  0.086959  0.187561
# fastSixes          1.537928e-01   1.000000   0.441079  0.121082  0.266456
# fastQuads          1.000131e-01   0.441079   1.000000  0.150042  0.295470
# quad               8.695944e-02   0.121082   0.150042  1.000000  0.137334
# triple             1.875608e-01   0.266456   0.295470  0.137334  1.000000
# double             9.633412e-02   0.116065   0.095224 -0.118258 -0.024306
# surface            2.514301e-01   0.369356   0.332485  0.121082  0.180011
# total_chairs       2.640790e-01   0.601428   0.758113  0.363444  0.536109
# Runs               3.220633e-01   0.550493   0.748566  0.301140  0.366107
# TerrainParks       1.549217e-01   0.340480   0.434860  0.243657  0.360847
# LongestRun_mi      2.197725e-01   0.372252   0.577042  0.198511  0.261977
# SkiableTerrain_ac  1.545475e-01   0.294594   0.394135  0.064448  0.137168
# Snow Making_ac     5.128537e-02   0.418182   0.522505  0.195866  0.299360
# daysOpenLastYear   4.950203e-02   0.270743   0.445419  0.193837  0.188507
# yearsOpen         -8.922601e-03  -0.009692  -0.016053 -0.028899 -0.035478
# averageSnowfall    8.884348e-02   0.175473   0.399696  0.071365  0.126008
# AdultWeekday       4.876649e-18   0.218252   0.536197  0.245951  0.274739
# AdultWeekend      -4.922574e-18   0.225992   0.530040  0.303266  0.309888
# projectedDaysOpen  4.376071e-02   0.256953   0.422246  0.214695  0.195754
# NightSkiing_ac    -1.080853e-17   0.035947   0.132342  0.170206  0.144924
#
#                      double   surface  total_chairs      Runs  TerrainParks  \
# summit_elev        0.106680 -0.039470      0.301986  0.573033      0.168547
# vertical_drop      0.171421  0.085946      0.548563  0.797288      0.341261
# base_elev          0.080290 -0.067700      0.203831  0.451071      0.105118
# trams              0.073272  0.267745      0.651348  0.685665      0.325465
# fastEight          0.096334  0.251430      0.264079  0.322063      0.154922
# fastSixes          0.116065  0.369356      0.601428  0.550493      0.340480
# fastQuads          0.095224  0.332485      0.758113  0.748566      0.434860
# quad              -0.118258  0.121082      0.363444  0.301140      0.243657
# triple            -0.024306  0.180011      0.536109  0.366107      0.360847
# double             1.000000  0.085508      0.366964  0.236585      0.193587
# surface            0.085508  1.000000      0.655417  0.311959      0.320151
# total_chairs       0.366964  0.655417      1.000000  0.770150      0.566226
# Runs               0.236585  0.311959      0.770150  1.000000      0.441753
# TerrainParks       0.193587  0.320151      0.566226  0.441753      1.000000
# LongestRun_mi      0.149062  0.157289      0.538195  0.720773      0.327867
# SkiableTerrain_ac  0.079850  0.088400      0.326318  0.494138      0.183289
# Snow Making_ac     0.105106  0.265005      0.552457  0.465956      0.336925
# daysOpenLastYear   0.101032  0.142727      0.412814  0.481266      0.275143
# yearsOpen         -0.030999  0.086640     -0.003592 -0.017620      0.031369
# averageSnowfall    0.092217 -0.108506      0.242117  0.519653      0.144109
# AdultWeekday       0.124928  0.001578      0.439834  0.585184      0.273045
# AdultWeekend       0.122794  0.018873      0.466225  0.563389      0.292728
# projectedDaysOpen  0.124311  0.096428      0.397842  0.479778      0.300882
# NightSkiing_ac     0.190596  0.011615      0.200932  0.188097      0.162440
#
#                    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# summit_elev             0.529771           0.468912        0.316131
# vertical_drop           0.759227           0.530349        0.466209
# base_elev               0.413270           0.406045        0.246614
# trams                   0.568705           0.342238        0.537990
# fastEight               0.219773           0.154547        0.051285
# fastSixes               0.372252           0.294594        0.418182
# fastQuads               0.577042           0.394135        0.522505
# quad                    0.198511           0.064448        0.195866
# triple                  0.261977           0.137168        0.299360
# double                  0.149062           0.079850        0.105106
# surface                 0.157289           0.088400        0.265005
# total_chairs            0.538195           0.326318        0.552457
# Runs                    0.720773           0.494138        0.465956
# TerrainParks            0.327867           0.183289        0.336925
# LongestRun_mi           1.000000           0.370229        0.498166
# SkiableTerrain_ac       0.370229           1.000000        0.287888
# Snow Making_ac          0.498166           0.287888        1.000000
# daysOpenLastYear        0.393587           0.325111        0.332351
# yearsOpen               0.003170          -0.030170       -0.011048
# averageSnowfall         0.468329           0.437016        0.258519
# AdultWeekday            0.512161           0.307647        0.313472
# AdultWeekend            0.480707           0.269553        0.315998
# projectedDaysOpen       0.429483           0.328890        0.322991
# NightSkiing_ac          0.104046           0.161423        0.177183
#
#                    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  \
# summit_elev                0.426314  -0.024759         0.693432  4.698100e-01
# vertical_drop              0.534877  -0.031188         0.664244  6.267366e-01
# base_elev                  0.355968  -0.019304         0.633957  3.755315e-01
# trams                      0.354562  -0.009907         0.293778  4.141931e-01
# fastEight                  0.049502  -0.008923         0.088843  4.876649e-18
# fastSixes                  0.270743  -0.009692         0.175473  2.182520e-01
# fastQuads                  0.445419  -0.016053         0.399696  5.361973e-01
# quad                       0.193837  -0.028899         0.071365  2.459506e-01
# triple                     0.188507  -0.035478         0.126008  2.747390e-01
# double                     0.101032  -0.030999         0.092217  1.249277e-01
# surface                    0.142727   0.086640        -0.108506  1.578117e-03
# total_chairs               0.412814  -0.003592         0.242117  4.398343e-01
# Runs                       0.481266  -0.017620         0.519653  5.851840e-01
# TerrainParks               0.275143   0.031369         0.144109  2.730448e-01
# LongestRun_mi              0.393587   0.003170         0.468329  5.121609e-01
# SkiableTerrain_ac          0.325111  -0.030170         0.437016  3.076467e-01
# Snow Making_ac             0.332351  -0.011048         0.258519  3.134717e-01
# daysOpenLastYear           1.000000   0.022116         0.473720  4.577895e-01
# yearsOpen                  0.022116   1.000000         0.028608  2.952954e-03
# averageSnowfall            0.473720   0.028608         1.000000  4.556629e-01
# AdultWeekday               0.457790   0.002953         0.455663  1.000000e+00
# AdultWeekend               0.456450   0.003481         0.380225  9.353086e-01
# projectedDaysOpen          0.865066   0.015179         0.524018  4.744307e-01
# NightSkiing_ac             0.175837   0.022484         0.307861  1.773220e-01
#
#                    AdultWeekend  projectedDaysOpen  NightSkiing_ac
# summit_elev        3.823537e-01           0.425014    1.422963e-01
# vertical_drop      5.842997e-01           0.550991    2.035365e-01
# base_elev          2.830623e-01           0.350272    1.039844e-01
# trams              4.099955e-01           0.332103    4.094253e-02
# fastEight         -4.922574e-18           0.043761   -1.080853e-17
# fastSixes          2.259918e-01           0.256953    3.594699e-02
# fastQuads          5.300403e-01           0.422246    1.323424e-01
# quad               3.032665e-01           0.214695    1.702057e-01
# triple             3.098883e-01           0.195754    1.449241e-01
# double             1.227935e-01           0.124311    1.905962e-01
# surface            1.887299e-02           0.096428    1.161522e-02
# total_chairs       4.662247e-01           0.397842    2.009322e-01
# Runs               5.633890e-01           0.479778    1.880967e-01
# TerrainParks       2.927278e-01           0.300882    1.624404e-01
# LongestRun_mi      4.807073e-01           0.429483    1.040459e-01
# SkiableTerrain_ac  2.695532e-01           0.328890    1.614227e-01
# Snow Making_ac     3.159985e-01           0.322991    1.771835e-01
# daysOpenLastYear   4.564496e-01           0.865066    1.758366e-01
# yearsOpen          3.480812e-03           0.015179    2.248439e-02
# averageSnowfall    3.802252e-01           0.524018    3.078608e-01
# AdultWeekday       9.353086e-01           0.474431    1.773220e-01
# AdultWeekend       1.000000e+00           0.457804    1.960035e-01
# projectedDaysOpen  4.578036e-01           1.000000    1.945337e-01
# NightSkiing_ac     1.960035e-01           0.194534    1.000000e+00

# %%
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(corr_mat,annot=True)
plt.show()

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %%
# Summit Elevation and Base Elevation are highly correlated and slightly redundant in their information (.98 correlation)
# Including Vertical Drop definitely makes one of these three features redunant. (.74 and .59 correlation)
# Days Open and Projected Days Open are highly correlated (some of their data was immuted onto each other). (.87 correlation)
# Adult Weekend and Adult Weekday are highly correlated (.87 correlation)
# Years Open has the lowest correlation with anything else. It would imply that newer resorts do not necessary have different features than older ones.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")
plt.show()

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now we will do the same for regions! 

fig, ax = plt.subplots(figsize=(10, 10))

x = pd.DataFrame(df.Region.value_counts())
region_names = list(x.index)
values = list(x.Region)

sns.barplot(x=values, y=region_names, palette='coolwarm')

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
df = df.drop(columns=['Region'])

# %%
# I will also drop "Summit Elevation" as well given that it can be derived from Base Elevation and Vertical Drop (and there Base Elevation is less correlated with Vertical Drop, so I will keep Base Elevation over Summit Elevation)
# I will also drop Projected Days Open given that some of its values were imputed from Days Open Last Year, and the fact that Projected Days Open is a less realiable data point.
# (I am also considering dropping Years Open given it is not correlated with anything, but I will keep it for now.)

df = df.drop(columns=['summit_elev','projectedDaysOpen'])

# %%
df.head()
# Out:
#                   Name    state  vertical_drop  base_elev  trams  fastEight  \
# 0       Alyeska Resort   Alaska           2500        250      1        0.0
# 1  Eaglecrest Ski Area   Alaska           1540       1200      0        0.0
# 2     Hilltop Ski Area   Alaska            294       1796      0        0.0
# 3     Arizona Snowbowl  Arizona           2300       9200      0        0.0
# 4  Sunrise Park Resort  Arizona           1800       9200      0        0.0
#
#    fastSixes  fastQuads  quad  triple  double  surface  total_chairs  Runs  \
# 0          0          2     2       0       0        2             7  76.0
# 1          0          0     0       0       4        0             4  36.0
# 2          0          0     0       1       0        2             3  13.0
# 3          1          0     2       2       1        2             8  55.0
# 4          0          1     2       3       1        0             7  65.0
#
#    TerrainParks  LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# 0           2.0            1.0             1610.0           113.0
# 1           1.0            2.0              640.0            60.0
# 2           1.0            1.0               30.0            30.0
# 3           4.0            2.0              777.0           104.0
# 4           2.0            1.2              800.0            80.0
#
#    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 0             150.0       60.0            669.0          65.0          85.0
# 1              45.0       44.0            350.0          47.0          53.0
# 2             150.0       36.0             69.0          30.0          34.0
# 3             122.0       81.0            260.0          89.0          89.0
# 4             115.0       49.0            250.0          74.0          78.0
#
#    NightSkiing_ac
# 0      550.000000
# 1      100.395722
# 2       30.000000
# 3      100.395722
# 4       80.000000

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
# filtering for only numeric data to display boxplots of numeric data only.
df_numeric = df._get_numeric_data()

for name in df_numeric:
    plt.figure()
    df_numeric.boxplot(column=[name])
# Out:
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = df.quantile(0.75)
# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3 - Q1
# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 

dfno = df[~((df < (Q1 - 1.5 * IQR)) | (df> (Q3 + 1.5 * IQR))).any(axis=1)]


# We now want to make a boxplot of this new dataframe dfno. 
dfno_boxplot = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))
plt.show()

# %%
print('Original Dataframe shape: ', df.shape)
print('Dataframe filtered for outliers 1.5 times outside of the IQR: ', dfno.shape)
# Out:
# Original Dataframe shape:  (330, 24)
# Dataframe filtered for outliers 1.5 times outside of the IQR:  (167, 24)

# %%
# This filtered dataframe is filtering almost  50% of the the rows from our dataset, way too many, many of which
# are accurate data. However, for this guided project we will filter out these outliers.

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
#Creating Histogram for Weekday and Weekend Prices
fig,(ax1, ax2) = plt.subplots(1, 2,figsize=(14,4))

ax1.hist(dfno.AdultWeekday)
ax2.hist(dfno.AdultWeekend)

# Labeling each histogram
ax1.set_xlabel('Price in Dollars')
ax1.set_ylabel('Frequency')
ax1.set_title('Weekday Prices')
ax2.set_xlabel('Price in Dollars')
ax2.set_ylabel('Frequency')
ax2.set_title('Weekend Prices')

plt.show()

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# I already droped Projected Days Open from the Dataframe (will bring it back if it proves necessary)
# 
plt.figure(figsize = (12,6))

dfno.daysOpenLastYear.hist()

plt.title('Days Open Last Year')
plt.xlabel('Days Open')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
# Below is a pairplot matrix. There is so many features here that it is hard to fully decipher the visual information
# presented in these graphs.

sns.pairplot(dfno)

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /Users/Mateo/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col1 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col5 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col6 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col7 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col8 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col9 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col10 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col11 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col12 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col13 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col14 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col15 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col16 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col17 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col18 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col19 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col20 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row0_col21 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col0 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col6 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col11 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col13 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col14 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col15 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col16 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col17 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col18 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col19 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col20 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row1_col21 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6b1f766_cc53_11ea_b464_a45e60ccc4d9row2_col15 {
#             background-color:  #3b4cc0;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
print('There are no features with of 0.95 correlation.')
print('I already dropped Projected Days Open and Summit Elevation.')
# Out:
# Features selected to drop include: []
# There are no features with of 0.95 correlation.
# I already dropped Projected Days Open and Summit Elevation.

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (167, 24)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop(dfno[to_drop], axis=1)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)

plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno['clusters'] = y_kmeans3

# %%
# Write your dataframe to csv 
dfno.to_csv('./data/step3_output.csv')
